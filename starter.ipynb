# %%
cd /home/dcor/niskhizov/AdversarialRendering/mitsuba/gsoup/src
# Out:
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/gsoup/src

# %%
import os
while True:
    os.system('/home/dcor/niskhizov/anaconda3/bin/python /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py')
# Out:
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/9bd9830d530a4f95a4beb86882214d15
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.024317119270563126
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029349906..1.1527987].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [04:11<5:46:46,  2.10s/it]
# Epoch 101, Loss: 0.0416664220392704
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.06998652..1.1576793].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [07:53<5:31:43,  2.03s/it]
# Epoch 201, Loss: 0.032233938574790955
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0046470463..1.151357].
#   3%|▎         | 300/10000 [11:35<6:12:01,  2.30s/it]
# Epoch 301, Loss: 0.03214094787836075
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.052234452..1.1138797].
#   4%|▍         | 400/10000 [15:17<6:01:30,  2.26s/it]
# Epoch 401, Loss: 0.04294934496283531
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.049425486..1.0870478].
#   5%|▌         | 500/10000 [18:57<5:40:16,  2.15s/it]
# Epoch 501, Loss: 0.017770100384950638
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0163484..1.0495006].
#   6%|▌         | 600/10000 [22:33<5:25:07,  2.08s/it]
# Epoch 601, Loss: 0.027890877798199654
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.085206285..1.2121811].
#   7%|▋         | 700/10000 [26:13<5:33:55,  2.15s/it]
# Epoch 701, Loss: 0.029717611148953438
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.019772146..1.0945206].
#   8%|▊         | 800/10000 [29:51<5:43:23,  2.24s/it]
# Epoch 801, Loss: 0.042316269129514694
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0013133064..1.2101687].
#   9%|▉         | 900/10000 [33:27<5:27:58,  2.16s/it]
# Epoch 901, Loss: 0.03218790888786316
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03630644..1.2039124].
#  10%|█         | 1000/10000 [37:01<5:34:35,  2.23s/it]
# Epoch 1001, Loss: 0.014423364773392677
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07062632..1.1020231].
#  11%|█         | 1100/10000 [40:36<5:13:32,  2.11s/it]
# Epoch 1101, Loss: 0.0432407408952713
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02201768..1.1480206].
#  12%|█▏        | 1200/10000 [44:10<5:34:46,  2.28s/it]
# Epoch 1201, Loss: 0.017055977135896683
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02320911..1.1092508].
#  13%|█▎        | 1300/10000 [47:43<5:05:38,  2.11s/it]
# Epoch 1301, Loss: 0.033878304064273834
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031869754..1.4071314].
#  14%|█▍        | 1400/10000 [51:17<5:11:59,  2.18s/it]
# Epoch 1401, Loss: 0.033191580325365067
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.030032702..1.057354].
#  15%|█▌        | 1500/10000 [54:47<4:46:23,  2.02s/it]
# Epoch 1501, Loss: 0.04409225285053253
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.013180003..1.1099617].
#  16%|█▌        | 1600/10000 [58:19<4:39:53,  2.00s/it]
# Epoch 1601, Loss: 0.022766204550862312
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004897326..1.1556149].
#  17%|█▋        | 1700/10000 [1:01:50<4:38:34,  2.01s/it]
# Epoch 1701, Loss: 0.036221832036972046
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.040581744..1.1698732].
#  18%|█▊        | 1800/10000 [1:05:24<5:05:34,  2.24s/it]
# Epoch 1801, Loss: 0.04009351134300232
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.012559518..1.1471373].
#  19%|█▉        | 1900/10000 [1:08:59<4:39:28,  2.07s/it]
# Epoch 1901, Loss: 0.03901290521025658
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020605944..1.1126926].
#  20%|██        | 2000/10000 [1:12:29<4:34:21,  2.06s/it]
# Epoch 2001, Loss: 0.0459301620721817
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0036502928..1.1450553].
#  21%|██        | 2100/10000 [1:15:59<4:28:50,  2.04s/it]
# Epoch 2101, Loss: 0.03934820741415024
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03920623..1.0524318].
#  22%|██▏       | 2200/10000 [1:19:30<4:40:47,  2.16s/it]
# Epoch 2201, Loss: 0.03993120416998863
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.007380292..1.1056539].
#  23%|██▎       | 2300/10000 [1:23:01<4:26:51,  2.08s/it]
# Epoch 2301, Loss: 0.040497273206710815
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.08309069..1.098379].
#  24%|██▍       | 2400/10000 [1:26:36<4:39:31,  2.21s/it]
# Epoch 2401, Loss: 0.04150601476430893
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.046226636..1.1379142].
#  25%|██▌       | 2500/10000 [1:30:08<4:18:00,  2.06s/it]
# Epoch 2501, Loss: 0.025236070156097412
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.014704436..1.0985729].
#  26%|██▌       | 2600/10000 [1:33:34<4:29:37,  2.19s/it]
# Epoch 2601, Loss: 0.04040587320923805
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.016716339..1.2310736].
#  27%|██▋       | 2700/10000 [1:37:06<4:11:34,  2.07s/it]
# Epoch 2701, Loss: 0.01926286332309246
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10178202..1.1316268].
#  27%|██▋       | 2700/10000 [1:37:08<4:22:39,  2.16s/it]
# Traceback (most recent call last):
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 579, in <module>
#     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 272, in render
#     final_image = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 88, in gaussian_glow
#     kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Dr.Jit encountered an unrecoverable error and will now shut
# down. Please re-run your program in debug mode to check for
# out-of-bounds reads, writes, and other sources of undefined
# behavior. You can do so by calling
#
#    dr.set_flag(dr.JitFlag.Debug, True)
#
# at the beginning of the program. If these additional checks
# fail to pinpoint the problem, then you have likely found a
# bug. We are happy to help investigate and fix the problem if
# you can you create a self-contained reproducer and submit it
# at https://github.com/mitsuba-renderer/drjit.
#
# The error message of this specific failure is as follows:
# >>> cuda_check(): API error 0700 (CUDA_ERROR_ILLEGAL_ADDRESS): "an illegal memory access was encountered" in /project/ext/drjit-core/src/init.cpp:462.
# terminate called after throwing an instance of 'nanobind::python_error'
#   what():  ImportError: sys.meta_path is None, Python is likely shutting down
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/e97b88c5f1ab45a1afb68de56cd12329
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.020609311759471893
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.090551265..1.0508871].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:32<6:01:06,  2.19s/it]
# Epoch 101, Loss: 0.04777226597070694
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.015262052..1.3198699].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [06:58<5:44:51,  2.11s/it]
# Epoch 201, Loss: 0.023156704381108284
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00064332783..1.1032263].
#   3%|▎         | 300/10000 [10:28<5:17:10,  1.96s/it]
# Epoch 301, Loss: 0.02223067171871662
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.041313563..1.0878301].
#   4%|▍         | 400/10000 [13:54<5:00:52,  1.88s/it]
# Epoch 401, Loss: 0.042844582349061966
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05300761..1.4910401].
#   5%|▌         | 500/10000 [17:27<5:18:40,  2.01s/it]
# Epoch 501, Loss: 0.030072221532464027
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.14870496..1.2635713].
#   6%|▌         | 600/10000 [21:06<5:25:45,  2.08s/it]
# Epoch 601, Loss: 0.02868354134261608
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.053406503..1.0773311].
#   7%|▋         | 700/10000 [24:46<5:56:45,  2.30s/it]
# Epoch 701, Loss: 0.029789648950099945
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.014664412..1.0328149].
#   8%|▊         | 800/10000 [28:19<5:23:09,  2.11s/it]
# Epoch 801, Loss: 0.03394337743520737
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0543601..1.0856334].
#   9%|▉         | 900/10000 [31:51<5:15:43,  2.08s/it]
# Epoch 901, Loss: 0.026324333623051643
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031787947..1.2270995].
#  10%|█         | 1000/10000 [35:19<5:09:47,  2.07s/it]
# Epoch 1001, Loss: 0.029271891340613365
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0035187975..1.0608603].
#  11%|█         | 1100/10000 [38:49<4:56:23,  2.00s/it]
# Epoch 1101, Loss: 0.039893701672554016
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.051652968..1.0463657].
#  12%|█▏        | 1200/10000 [42:16<5:04:12,  2.07s/it]
# Epoch 1201, Loss: 0.037746500223875046
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.02244874..1.0782013].
#  13%|█▎        | 1300/10000 [45:46<5:11:21,  2.15s/it]
# Epoch 1301, Loss: 0.038339484483003616
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.022569463..1.109853].
#  14%|█▍        | 1400/10000 [49:15<4:52:10,  2.04s/it]
# Epoch 1401, Loss: 0.033483002334833145
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.016890705..1.2600887].
#  15%|█▌        | 1500/10000 [52:44<4:54:52,  2.08s/it]
# Epoch 1501, Loss: 0.02172592468559742
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.01971829..1.0019091].
#  16%|█▌        | 1600/10000 [56:12<4:38:52,  1.99s/it]
# Epoch 1601, Loss: 0.0354810431599617
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031352263..1.0634425].
#  17%|█▋        | 1700/10000 [59:38<4:33:35,  1.98s/it]
# Epoch 1701, Loss: 0.028548583388328552
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029847544..1.1086673].
#  18%|█▊        | 1800/10000 [1:03:04<4:41:48,  2.06s/it]
# Epoch 1801, Loss: 0.02200506441295147
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.063153505..1.0921118].
#  19%|█▉        | 1900/10000 [1:06:32<4:36:59,  2.05s/it]
# Epoch 1901, Loss: 0.020414981991052628
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.040512543..1.1702175].
#  20%|██        | 2000/10000 [1:10:00<4:39:03,  2.09s/it]
# Epoch 2001, Loss: 0.024689698591828346
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020802595..1.2072606].
#  21%|██        | 2100/10000 [1:13:38<4:53:17,  2.23s/it]
# Epoch 2101, Loss: 0.028766844421625137
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06930589..1.0977583].
#  22%|██▏       | 2200/10000 [1:17:17<4:36:40,  2.13s/it]
# Epoch 2201, Loss: 0.024508463218808174
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.046423078..1.1142471].
#  23%|██▎       | 2300/10000 [1:20:57<4:31:51,  2.12s/it]
# Epoch 2301, Loss: 0.034338220953941345
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.017635293..1.0640973].
#  24%|██▍       | 2400/10000 [1:27:01<4:42:40,  2.23s/it]
# Epoch 2401, Loss: 0.03677864372730255
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.024340957..1.2100687].
#  25%|██▌       | 2500/10000 [1:30:44<10:32:59,  5.06s/it]
# Epoch 2501, Loss: 0.02315436862409115
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07478618..1.2279248].
#  26%|██▌       | 2600/10000 [1:37:35<31:10:53, 15.17s/it]
# Epoch 2601, Loss: 0.03284679725766182
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0037281215..1.1240036].
#  27%|██▋       | 2700/10000 [1:49:49<4:13:23,  2.08s/it]
# Epoch 2701, Loss: 0.01625346764922142
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.029790148..0.7980041].
#  27%|██▋       | 2701/10000 [1:49:53<4:56:58,  2.44s/it]
# Traceback (most recent call last):
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 500, in <module>
#     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 272, in render
#     final_image = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 88, in gaussian_glow
#     kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Dr.Jit encountered an unrecoverable error and will now shut
# down. Please re-run your program in debug mode to check for
# out-of-bounds reads, writes, and other sources of undefined
# behavior. You can do so by calling
#
#    dr.set_flag(dr.JitFlag.Debug, True)
#
# at the beginning of the program. If these additional checks
# fail to pinpoint the problem, then you have likely found a
# bug. We are happy to help investigate and fix the problem if
# you can you create a self-contained reproducer and submit it
# at https://github.com/mitsuba-renderer/drjit.
#
# The error message of this specific failure is as follows:
# >>> cuda_check(): API error 0700 (CUDA_ERROR_ILLEGAL_ADDRESS): "an illegal memory access was encountered" in /project/ext/drjit-core/src/init.cpp:462.
# terminate called after throwing an instance of 'nanobind::python_error'
#   what():  ImportError: sys.meta_path is None, Python is likely shutting down
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/44512bf08c2d4a56b564558e172825c4
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.028828032314777374
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.067924485..1.3857219].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:31<5:25:50,  1.97s/it]
# Epoch 101, Loss: 0.03224124014377594
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01768449..1.2235961].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [07:01<5:51:38,  2.15s/it]
# Epoch 201, Loss: 0.029941055923700333
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07961386..1.304723].
#   3%|▎         | 300/10000 [10:30<5:44:23,  2.13s/it]
# Epoch 301, Loss: 0.028102943673729897
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04784283..1.0725105].
#   4%|▍         | 400/10000 [14:02<5:31:58,  2.07s/it]
# Epoch 401, Loss: 0.057080961763858795
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.041494653..1.1229016].
#   5%|▌         | 500/10000 [17:30<5:18:13,  2.01s/it]
# Epoch 501, Loss: 0.035206109285354614
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.015137047..1.1792006].
#   6%|▌         | 600/10000 [21:04<6:19:18,  2.42s/it]
# Epoch 601, Loss: 0.08722113072872162
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07653415..0.99719685].
#   7%|▋         | 700/10000 [24:44<5:40:54,  2.20s/it]
# Epoch 701, Loss: 0.024220721796154976
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.020294026..1.1558179].
#   8%|▊         | 800/10000 [28:25<5:23:19,  2.11s/it]
# Epoch 801, Loss: 0.028997184708714485
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.012232766..1.1306833].
#   9%|▉         | 900/10000 [31:57<5:07:14,  2.03s/it]
# Epoch 901, Loss: 0.019653448835015297
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010131188..1.1036446].
#  10%|█         | 1000/10000 [35:27<5:00:37,  2.00s/it]
# Epoch 1001, Loss: 0.019602857530117035
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.01845567..1.1128755].
#  11%|█         | 1100/10000 [38:55<4:45:22,  1.92s/it]
# Epoch 1101, Loss: 0.02684609964489937
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0053720623..1.2376665].
#  12%|█▏        | 1200/10000 [42:26<4:53:50,  2.00s/it]
# Epoch 1201, Loss: 0.032473381608724594
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.02108778..1.3830618].
#  13%|█▎        | 1300/10000 [45:59<5:18:19,  2.20s/it]
# Epoch 1301, Loss: 0.02458270452916622
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10070744..1.0858865].
#  14%|█▍        | 1400/10000 [49:45<5:10:43,  2.17s/it]
# Epoch 1401, Loss: 0.040688399225473404
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05578278..1.2226833].
#  15%|█▌        | 1500/10000 [53:27<4:58:08,  2.10s/it]
# Epoch 1501, Loss: 0.01771911419928074
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04602568..1.1031913].
#  16%|█▌        | 1600/10000 [56:56<4:38:34,  1.99s/it]
# Epoch 1601, Loss: 0.017419680953025818
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.08565195..1.2427354].
#  17%|█▋        | 1700/10000 [1:00:27<4:49:48,  2.09s/it]
# Epoch 1701, Loss: 0.035277314484119415
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0016221106..1.1722927].
#  18%|█▊        | 1800/10000 [1:03:58<4:54:27,  2.15s/it]
# Epoch 1801, Loss: 0.03677436709403992
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00042021275..1.1127002].
#  19%|█▉        | 1900/10000 [1:07:29<4:39:59,  2.07s/it]
# Epoch 1901, Loss: 0.02263324335217476
#  20%|██        | 2000/10000 [1:11:01<4:34:32,  2.06s/it]
# Epoch 2001, Loss: 0.02206292748451233
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10078994..1.0961522].
#  21%|██        | 2100/10000 [1:14:36<4:54:20,  2.24s/it]
# Epoch 2101, Loss: 0.01852385513484478
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.015318736..1.0620036].
#  22%|██▏       | 2200/10000 [1:18:09<4:37:49,  2.14s/it]
# Epoch 2201, Loss: 0.04616589471697807
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.057998434..1.1231408].
#  23%|██▎       | 2300/10000 [1:21:40<4:33:19,  2.13s/it]
# Epoch 2301, Loss: 0.025820860639214516
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011182994..1.0816808].
#  24%|██▍       | 2400/10000 [1:25:14<4:09:11,  1.97s/it]
# Epoch 2401, Loss: 0.025830330327153206
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0031343326..1.018512].
#  25%|██▌       | 2500/10000 [1:28:46<4:30:37,  2.16s/it]
# Epoch 2501, Loss: 0.03287027031183243
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0043841824..1.0727988].
#  26%|██▌       | 2600/10000 [1:32:18<4:24:18,  2.14s/it]
# Epoch 2601, Loss: 0.051718294620513916
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.18440464..1.1075369].
#  27%|██▋       | 2700/10000 [1:35:48<4:23:11,  2.16s/it]
# Epoch 2701, Loss: 0.024801155552268028
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06708957..1.3179146].
#  27%|██▋       | 2700/10000 [1:35:50<4:19:08,  2.13s/it]
# Traceback (most recent call last):
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 579, in <module>
#     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 272, in render
#     final_image = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 88, in gaussian_glow
#     kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Dr.Jit encountered an unrecoverable error and will now shut
# down. Please re-run your program in debug mode to check for
# out-of-bounds reads, writes, and other sources of undefined
# behavior. You can do so by calling
#
#    dr.set_flag(dr.JitFlag.Debug, True)
#
# at the beginning of the program. If these additional checks
# fail to pinpoint the problem, then you have likely found a
# bug. We are happy to help investigate and fix the problem if
# you can you create a self-contained reproducer and submit it
# at https://github.com/mitsuba-renderer/drjit.
#
# The error message of this specific failure is as follows:
# >>> cuda_check(): API error 0700 (CUDA_ERROR_ILLEGAL_ADDRESS): "an illegal memory access was encountered" in /project/ext/drjit-core/src/init.cpp:462.
# terminate called after throwing an instance of 'nanobind::python_error'
#   what():  ImportError: sys.meta_path is None, Python is likely shutting down
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/5a370c87690e4acb98131f6df93698ea
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.022563930600881577
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0092685..1.0606077].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:37<5:17:42,  1.93s/it]
# Epoch 101, Loss: 0.04045538604259491
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011808455..1.0876474].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [07:05<5:18:46,  1.95s/it]
# Epoch 201, Loss: 0.022897936403751373
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010547936..1.0474331].
#   3%|▎         | 300/10000 [10:32<5:39:29,  2.10s/it]
# Epoch 301, Loss: 0.022335365414619446
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010482393..1.0974088].
#   4%|▍         | 400/10000 [14:01<5:38:27,  2.12s/it]
# Epoch 401, Loss: 0.04418496787548065
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00044617802..1.1686233].
#   5%|▌         | 500/10000 [17:30<5:38:30,  2.14s/it]
# Epoch 501, Loss: 0.037525273859500885
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0027588904..1.1626908].
#   6%|▌         | 600/10000 [21:00<5:48:36,  2.23s/it]
# Epoch 601, Loss: 0.024534836411476135
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09095244..1.1105872].
#   7%|▋         | 700/10000 [24:31<5:13:42,  2.02s/it]
# Epoch 701, Loss: 0.0240554790943861
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.27012086..1.204062].
#   8%|▊         | 800/10000 [27:57<5:18:10,  2.08s/it]
# Epoch 801, Loss: 0.03547431156039238
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.023873478..1.0960993].
#   9%|▉         | 900/10000 [31:27<5:12:46,  2.06s/it]
# Epoch 901, Loss: 0.027318328619003296
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.015698597..1.0765975].
#  10%|█         | 1000/10000 [35:00<5:18:13,  2.12s/it]
# Epoch 1001, Loss: 0.04918310418725014
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0079217255..1.1383822].
#  11%|█         | 1100/10000 [38:33<5:26:10,  2.20s/it]
# Epoch 1101, Loss: 0.017547227442264557
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018675812..1.0961481].
#  12%|█▏        | 1200/10000 [42:02<5:21:22,  2.19s/it]
# Epoch 1201, Loss: 0.03540528565645218
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07182257..1.0821059].
#  13%|█▎        | 1300/10000 [45:33<4:59:46,  2.07s/it]
# Epoch 1301, Loss: 0.030156314373016357
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00069408864..1.0741166].
#  14%|█▍        | 1400/10000 [49:06<4:36:14,  1.93s/it]
# Epoch 1401, Loss: 0.03951489180326462
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031491056..1.0797309].
#  15%|█▌        | 1500/10000 [52:42<5:12:30,  2.21s/it]
# Epoch 1501, Loss: 0.03113444894552231
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.040531248..1.0915552].
#  16%|█▌        | 1600/10000 [56:18<4:52:38,  2.09s/it]
# Epoch 1601, Loss: 0.04161492735147476
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002471447..1.1593453].
#  17%|█▋        | 1700/10000 [59:51<4:42:50,  2.04s/it]
# Epoch 1701, Loss: 0.045903127640485764
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11538267..1.0416933].
#  18%|█▊        | 1800/10000 [1:03:29<4:29:46,  1.97s/it]
# Epoch 1801, Loss: 0.02503678947687149
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.071148485..1.174703].
#  19%|█▉        | 1900/10000 [1:07:04<5:07:20,  2.28s/it]
# Epoch 1901, Loss: 0.053008340299129486
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.08737266..1.1778909].
#  20%|██        | 2000/10000 [1:10:39<4:32:28,  2.04s/it]
# Epoch 2001, Loss: 0.0071622529067099094
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.11071751..1.0999538].
#  21%|██        | 2100/10000 [1:14:15<4:34:49,  2.09s/it]
# Epoch 2101, Loss: 0.023011038079857826
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12562492..1.0879614].
#  22%|██▏       | 2200/10000 [1:17:54<4:41:15,  2.16s/it]
# Epoch 2201, Loss: 0.02236543968319893
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.030581623..1.0528817].
#  23%|██▎       | 2300/10000 [1:21:34<4:36:19,  2.15s/it]
# Epoch 2301, Loss: 0.024057157337665558
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.006038457..1.0630586].
#  24%|██▍       | 2400/10000 [1:25:09<4:29:38,  2.13s/it]
# Epoch 2401, Loss: 0.03683746978640556
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.033375144..1.0738137].
#  25%|██▌       | 2500/10000 [1:28:41<4:26:21,  2.13s/it]
# Epoch 2501, Loss: 0.02206311747431755
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.032410495..1.0282195].
#  26%|██▌       | 2600/10000 [1:32:16<4:34:51,  2.23s/it]
# Epoch 2601, Loss: 0.025990352034568787
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.016310796..1.0999597].
#  27%|██▋       | 2700/10000 [1:35:46<4:15:58,  2.10s/it]
# Epoch 2701, Loss: 0.023721588775515556
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020019338..1.1034945].
#  27%|██▋       | 2700/10000 [1:35:49<4:19:03,  2.13s/it]
# Traceback (most recent call last):
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 579, in <module>
#     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 272, in render
#     final_image = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 88, in gaussian_glow
#     kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Dr.Jit encountered an unrecoverable error and will now shut
# down. Please re-run your program in debug mode to check for
# out-of-bounds reads, writes, and other sources of undefined
# behavior. You can do so by calling
#
#    dr.set_flag(dr.JitFlag.Debug, True)
#
# at the beginning of the program. If these additional checks
# fail to pinpoint the problem, then you have likely found a
# bug. We are happy to help investigate and fix the problem if
# you can you create a self-contained reproducer and submit it
# at https://github.com/mitsuba-renderer/drjit.
#
# The error message of this specific failure is as follows:
# >>> cuda_check(): API error 0700 (CUDA_ERROR_ILLEGAL_ADDRESS): "an illegal memory access was encountered" in /project/ext/drjit-core/src/init.cpp:462.
# terminate called after throwing an instance of 'nanobind::python_error'
#   what():  ImportError: sys.meta_path is None, Python is likely shutting down
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/ef93d0677ae843b8b3f2e579f37f2cf1
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.014503664337098598
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.049960718..1.0637529].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:36<5:52:09,  2.13s/it]
# Epoch 101, Loss: 0.02413434535264969
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.051581264..1.1528083].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [07:07<5:26:50,  2.00s/it]
# Epoch 201, Loss: 0.035701896995306015
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.013598725..1.0901192].
#   3%|▎         | 300/10000 [10:34<5:32:15,  2.06s/it]
# Epoch 301, Loss: 0.018802806735038757
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.057791017..1.1742445].
#   4%|▍         | 400/10000 [14:05<5:17:40,  1.99s/it]
# Epoch 401, Loss: 0.02285187318921089
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05351989..1.0451417].
#   5%|▌         | 500/10000 [17:36<5:10:13,  1.96s/it]
# Epoch 501, Loss: 0.045675765722990036
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12144241..1.1075628].
#   6%|▌         | 600/10000 [21:08<5:26:32,  2.08s/it]
# Epoch 601, Loss: 0.03990885987877846
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.018077075..1.08997].
#   7%|▋         | 700/10000 [24:36<5:30:47,  2.13s/it]
# Epoch 701, Loss: 0.02637092024087906
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01793383..1.1018648].
#   8%|▊         | 800/10000 [28:04<5:07:29,  2.01s/it]
# Epoch 801, Loss: 0.030272910371422768
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0048505664..1.1701396].
#   9%|▉         | 900/10000 [31:35<5:04:22,  2.01s/it]
# Epoch 901, Loss: 0.017171410843729973
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031876475..1.0722965].
#  10%|█         | 1000/10000 [35:06<5:16:51,  2.11s/it]
# Epoch 1001, Loss: 0.024322805926203728
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.030052572..1.0860264].
#  11%|█         | 1100/10000 [38:34<5:10:31,  2.09s/it]
# Epoch 1101, Loss: 0.04264942184090614
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.041057646..1.1427429].
#  12%|█▏        | 1200/10000 [42:09<5:08:21,  2.10s/it]
# Epoch 1201, Loss: 0.01764799654483795
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06517638..1.0665334].
#  13%|█▎        | 1300/10000 [45:37<5:17:30,  2.19s/it]
# Epoch 1301, Loss: 0.043219830840826035
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.053069457..1.0905725].
#  14%|█▍        | 1400/10000 [51:24<5:01:18,  2.10s/it]
# Epoch 1401, Loss: 0.0335766077041626
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0152284205..1.0956444].
#  15%|█▌        | 1500/10000 [54:52<5:15:37,  2.23s/it]
# Epoch 1501, Loss: 0.01762247085571289
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.04140514..1.168669].
#  16%|█▌        | 1600/10000 [58:24<4:53:22,  2.10s/it]
# Epoch 1601, Loss: 0.02974630333483219
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0006674379..1.0218477].
#  17%|█▋        | 1700/10000 [1:01:51<4:39:47,  2.02s/it]
# Epoch 1701, Loss: 0.017554830759763718
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.040550403..1.154249].
#  18%|█▊        | 1800/10000 [1:05:27<4:34:38,  2.01s/it]
# Epoch 1801, Loss: 0.03449146822094917
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0077570677..1.1113787].
#  19%|█▉        | 1900/10000 [1:08:59<4:44:48,  2.11s/it]
# Epoch 1901, Loss: 0.017286261543631554
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07047022..1.0896587].
#  20%|██        | 2000/10000 [1:12:31<4:48:16,  2.16s/it]
# Epoch 2001, Loss: 0.03601124510169029
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0013502985..1.1705656].
#  21%|██        | 2100/10000 [1:16:03<4:35:14,  2.09s/it]
# Epoch 2101, Loss: 0.03843427449464798
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.018762827..1.1103369].
#  22%|██▏       | 2200/10000 [1:19:34<4:31:30,  2.09s/it]
# Epoch 2201, Loss: 0.05277904495596886
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009261057..1.1072302].
#  23%|██▎       | 2300/10000 [1:23:07<4:31:21,  2.11s/it]
# Epoch 2301, Loss: 0.04872246831655502
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0023313463..1.1534775].
#  23%|██▎       | 2343/10000 [1:24:39<4:38:18,  2.18s/it]Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Assertion failed in /project/ext/drjit-core/ext/nanothread/src/queue.cpp:356: remain == 1
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/8c08db6c79b94af6980c44bce5cfbb81
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.021060030907392502
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.023976445..1.2002754].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:28<5:43:10,  2.08s/it]
# Epoch 101, Loss: 0.015623409301042557
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.11181049..1.123159].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [06:55<5:53:17,  2.16s/it]
# Epoch 201, Loss: 0.021402334794402122
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.014269128..1.0717732].
#   3%|▎         | 300/10000 [10:25<5:13:54,  1.94s/it]
# Epoch 301, Loss: 0.01782049424946308
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.3290398..1.1353384].
#   4%|▍         | 400/10000 [13:52<5:33:35,  2.08s/it]
# Epoch 401, Loss: 0.03541131317615509
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031175137..1.0479269].
#   5%|▌         | 500/10000 [17:19<5:21:27,  2.03s/it]
# Epoch 501, Loss: 0.010873395949602127
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020785749..1.1537223].
#   6%|▌         | 600/10000 [20:46<5:05:20,  1.95s/it]
# Epoch 601, Loss: 0.025534754619002342
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0013215393..1.1243644].
#   7%|▋         | 700/10000 [24:15<5:32:33,  2.15s/it]
# Epoch 701, Loss: 0.03418419137597084
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.102023765..1.0734406].
#   8%|▊         | 800/10000 [27:43<5:04:12,  1.98s/it]
# Epoch 801, Loss: 0.028201056644320488
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.053334355..1.1637896].
#   9%|▉         | 900/10000 [31:13<4:56:54,  1.96s/it]
# Epoch 901, Loss: 0.024507082998752594
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0014635324..1.0846277].
#  10%|█         | 1000/10000 [34:46<5:11:53,  2.08s/it]
# Epoch 1001, Loss: 0.03568176552653313
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.05829543..1.1500087].
#  11%|█         | 1100/10000 [38:20<4:56:38,  2.00s/it]
# Epoch 1101, Loss: 0.028776634484529495
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.028241068..1.1236513].
#  12%|█▏        | 1200/10000 [41:54<5:04:24,  2.08s/it]
# Epoch 1201, Loss: 0.02244897373020649
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.059715435..1.1712399].
#  13%|█▎        | 1300/10000 [45:25<5:11:39,  2.15s/it]
# Epoch 1301, Loss: 0.025430765002965927
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.006473601..1.2139982].
#  14%|█▍        | 1400/10000 [48:52<4:43:02,  1.97s/it]
# Epoch 1401, Loss: 0.038182783871889114
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.014280811..1.2201631].
#  15%|█▌        | 1500/10000 [52:20<4:56:19,  2.09s/it]
# Epoch 1501, Loss: 0.03441552817821503
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0032063425..1.2024267].
#  16%|█▌        | 1600/10000 [55:50<4:47:51,  2.06s/it]
# Epoch 1601, Loss: 0.009166259318590164
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.086716205..1.0809808].
#  17%|█▋        | 1700/10000 [59:23<4:53:17,  2.12s/it]
# Epoch 1701, Loss: 0.019532587379217148
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04440394..1.0853531].
#  18%|█▊        | 1800/10000 [1:02:54<4:32:15,  1.99s/it]
# Epoch 1801, Loss: 0.022704817354679108
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07686486..1.0787015].
#  19%|█▉        | 1900/10000 [1:06:20<4:37:31,  2.06s/it]
# Epoch 1901, Loss: 0.019504856318235397
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.004948944..1.0870342].
#  20%|██        | 2000/10000 [1:09:51<4:37:48,  2.08s/it]
# Epoch 2001, Loss: 0.01943584904074669
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05165936..1.0839084].
#  21%|██        | 2100/10000 [1:13:21<4:20:35,  1.98s/it]
# Epoch 2101, Loss: 0.03553929552435875
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0134262..1.0861905].
#  22%|██▏       | 2200/10000 [1:16:51<4:31:22,  2.09s/it]
# Epoch 2201, Loss: 0.03322020173072815
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0033822358..1.2579176].
#  23%|██▎       | 2300/10000 [1:20:24<4:29:43,  2.10s/it]
# Epoch 2301, Loss: 0.04185256361961365
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.098229975..1.0930461].
#  24%|██▍       | 2400/10000 [1:23:55<4:07:24,  1.95s/it]
# Epoch 2401, Loss: 0.021410129964351654
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.019738674..1.0489789].
#  25%|██▌       | 2500/10000 [1:27:26<4:23:39,  2.11s/it]
# Epoch 2501, Loss: 0.019311660900712013
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.044282496..1.1405042].
#  26%|██▌       | 2600/10000 [1:30:59<4:02:28,  1.97s/it]
# Epoch 2601, Loss: 0.01782875508069992
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.018324792..1.0448377].
#  27%|██▋       | 2700/10000 [1:34:30<4:07:13,  2.03s/it]
# Epoch 2701, Loss: 0.024796443060040474
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.034092203..1.0862684].
#  27%|██▋       | 2700/10000 [1:34:33<4:15:38,  2.10s/it]
# Traceback (most recent call last):
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 579, in <module>
#     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 272, in render
#     final_image = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py", line 88, in gaussian_glow
#     kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Dr.Jit encountered an unrecoverable error and will now shut
# down. Please re-run your program in debug mode to check for
# out-of-bounds reads, writes, and other sources of undefined
# behavior. You can do so by calling
#
#    dr.set_flag(dr.JitFlag.Debug, True)
#
# at the beginning of the program. If these additional checks
# fail to pinpoint the problem, then you have likely found a
# bug. We are happy to help investigate and fix the problem if
# you can you create a self-contained reproducer and submit it
# at https://github.com/mitsuba-renderer/drjit.
#
# The error message of this specific failure is as follows:
# >>> cuda_check(): API error 0700 (CUDA_ERROR_ILLEGAL_ADDRESS): "an illegal memory access was encountered" in /project/ext/drjit-core/src/init.cpp:462.
# terminate called after throwing an instance of 'nanobind::python_error'
#   what():  ImportError: sys.meta_path is None, Python is likely shutting down
# Aborted (core dumped)
# <module 'mitsuba.mitsuba_alias' from '/home/dcor/niskhizov/anaconda3/lib/python3.12/site-packages/mitsuba/mitsuba_alias.cpython-312-x86_64-linux-gnu.so'>
# Loading existing models...
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/b44164859f8a46979b86e8d0fb2ae341
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.014514164999127388
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.12466426..1.0428846].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   1%|          | 100/10000 [03:37<5:38:56,  2.05s/it]
# Epoch 101, Loss: 0.020050574094057083
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.023054898..1.0765681].
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:557: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /home/dcor/niskhizov/AdversarialRendering/mitsuba/train_fixed_anchors_v2.py:559: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#   2%|▏         | 200/10000 [07:08<5:27:39,  2.01s/it]
# Epoch 201, Loss: 0.022045187652111053
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008421391..1.0134112].
#   3%|▎         | 300/10000 [10:35<5:42:05,  2.12s/it]
# Epoch 301, Loss: 0.01775878109037876
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.08947724..1.113983].
#   4%|▍         | 400/10000 [14:05<5:18:42,  1.99s/it]
# Epoch 401, Loss: 0.026381850242614746
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006354898..1.0903834].
#   5%|▌         | 500/10000 [17:35<5:53:24,  2.23s/it]
# Epoch 501, Loss: 0.03841092064976692
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06848174..1.2079824].
#   6%|▌         | 600/10000 [21:01<5:27:46,  2.09s/it]
# Epoch 601, Loss: 0.036656010895967484
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018577054..1.1463691].
#   7%|▋         | 700/10000 [24:32<5:35:31,  2.16s/it]
# Epoch 701, Loss: 0.01976815238595009
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.012147069..1.1285026].
#   8%|▊         | 800/10000 [28:01<5:07:22,  2.00s/it]
# Epoch 801, Loss: 0.018779056146740913
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04939969..1.0782182].
#   8%|▊         | 828/10000 [29:00<5:10:17,  2.03s/it]

# %%
import comet_ml
from comet_ml.integration.pytorch import watch

comet_ml.login(project_name="fewshotadapter")



from datetime import datetime
import os
import sys
os.chdir('/home/dcor/niskhizov/AdversarialRendering/mitsuba/gsoup/src')
sys.path.insert(0, '/home/dcor/niskhizov/AdversarialRendering/mitsuba/gsoup/src')

import glob
import mitsuba as mi
import drjit as dr
import numpy as np
import cv2
from gsoup.image import (
    change_brightness,
    add_alpha,
    resize,
    tonemap_reinhard,
    linear_to_srgb,
)
import matplotlib.pyplot as plt

mi.set_variant(
    "cuda_ad_rgb"
    # "scalar_rgb"
)  # "llvm_ad_rgb", "scalar_rgb" # must set before defining the emitter


patchs = glob.glob('/home/dcor/niskhizov/AdversarialRendering/botorch_snapshots/*patch*')

anchors_dir = '/home/dcor/niskhizov/rgb_patterns_0_50_150/'
anchors_paths = glob.glob(f'{anchors_dir}/*')

cam_wh=(256, 256)
cam_fov=45
proj_wh=(256, 256)
proj_fov=45
ambient_color=list(np.array([0.1, 0.1, 0.1] )*10)
proj_brightness = 30

spp=256
proj_response_mode = "srgb"

import gsoup
from gsoup.projector_plugin_mitsuba import ProjectorPy
import mitsuba as mi
mi.register_emitter("projector_py", lambda props: ProjectorPy(props))

# roughness = list(range(0.1,0.8, 0.1))
# metallics  = list(range(0, 1.0, 0.1))

roughness = list(np.arange(0.1, 0.8, 0.1))

metallics  = list(np.arange(0, 1.0, 0.1))

import torch
import torch.nn.functional as F




def create_gaussian_kernel_2d(kernel_size, sigma):
    """Create a 2D Gaussian kernel using PyTorch"""
    coords = torch.arange(kernel_size, dtype=torch.float32) - kernel_size // 2
    g = torch.exp(-(coords ** 2) / (2 * sigma ** 2))
    g = g / g.sum()
    
    # Create 2D kernel
    kernel_2d = g.unsqueeze(0) * g.unsqueeze(1)
    return kernel_2d.unsqueeze(0).unsqueeze(0)

def gaussian_glow(image, glow_radius, glow_strength):
    """Apply Gaussian blur using PyTorch convolution with groups (no for loops)"""
    # Ensure kernel size is odd
    kernel_size = glow_radius

    if kernel_size % 2 == 0:
        kernel_size += 1
    

    sigma = glow_radius / 6.0  # Adjust sigma based on radius
    # Create Gaussian kernel
    kernel = create_gaussian_kernel_2d(kernel_size, sigma).to(image.device)
    
    # Reshape image from (H, W, C) to (1, C, H, W) for conv2d
    img_4d = image.permute(2, 0, 1).unsqueeze(0)  # (1, 3, H, W)
    
    # Repeat kernel for each channel: (3, 1, kernel_size, kernel_size)
    kernel_3ch = kernel.repeat(3, 1, 1, 1)
    
    # Apply convolution with groups=3 (one kernel per channel)
    padding = kernel_size // 2
    blurred_4d = F.conv2d(img_4d, kernel_3ch, padding=padding, groups=3)
    
    # Convert back to (H, W, C) format
    img_blurred = blurred_4d.squeeze(0).permute(1, 2, 0)

    img_blended = image + img_blurred * glow_strength

    
    return img_blended


def gaussian_blur_torch(image, sigma):

    device = image.device if hasattr(image, 'device') else 'cpu'

    # Create Gaussian kernel
    kernel_size = int(2 * sigma * 3) + 1  # 6 sigma rule
    if kernel_size % 2 == 0:
        kernel_size += 1
    
    # Create 1D Gaussian kernel - ensure it's on the same device
    x = torch.arange(kernel_size, dtype=torch.float32, device=device) - kernel_size // 2
    gauss_1d = torch.exp(-(x ** 2) / (2 * sigma ** 2))
    gauss_1d = gauss_1d / gauss_1d.sum()
    
    # Create 2D kernel
    gauss_2d = gauss_1d.unsqueeze(0) * gauss_1d.unsqueeze(1)
    gauss_2d = gauss_2d.unsqueeze(0).unsqueeze(0)


    gauss_2d_rgb = gauss_2d.repeat(3, 1, 1, 1)  # Repeat for RGB channels
    
    # Apply convolution with padding
    padding = kernel_size // 2
    blurred = F.conv2d(image, gauss_2d_rgb, padding=padding,groups=3)
    
    return blurred.squeeze(0).squeeze(0)


def generate_random_scene(test=False):
    """
    Generate a random scene dictionary for Mitsuba.
    """            
    if test:
        random_patch = np.random.choice(patchs[-100:])
    else:
        random_patch = np.random.choice(patchs[:-100])
    roughnes =  np.random.choice(roughness)
    metallic = np.random.choice(metallics)

    proj_brightness = np.random.uniform(1.0, 10.0)

    ambient_color_scale = np.random.uniform(0.1, 1.0)

    ambient_color=list(np.array([1.0,1.0,1.0] )*ambient_color_scale)

    focus_distance = np.random.uniform(1.0, 20.0)

    scene_dict = {

                    "type": "scene",

                    "integrator": {
                        "type": "path",
                        "hide_emitters": True,
                        "max_depth": 6,
                    },
                    "camera": {
                        "type": "thinlens",
                        'aperture_radius': 0.02,  # control DoF (0.0 = pinhole)
                        'focus_distance': focus_distance,  # meters to subject
                        "fov": cam_fov,
                        
                        "to_world": mi.ScalarTransform4f().look_at(
                            origin=[0.1, 0, 0.0],  # along +X axis
                            target=[0, 0, 0],
                            up=[0, 0, 1],  # Z-up
                        ),
                        "film": {
                            "type": "hdrfilm",
                            "width": cam_wh[0],
                            "height": cam_wh[1],
                            "pixel_format": "rgba",
                            "rfilter": {"type": "box"},
                        },
                        "sampler": {
                            "type": "independent",
                            "sample_count": spp,  # number of samples per pixel
                        },
                    },

                    "wall3": {
                        "type": "rectangle",
                        "to_world": mi.ScalarTransform4f()
                        .translate([-2.0, 0.0, 0.0])
                        .rotate([0, 1, 0], 90),
                        "bsdf": 
                        {

                        'type': 'principled',
                        'base_color': {
                            'type': 'bitmap',
                            'filename': f'{random_patch}',

                        },
                        'roughness' : roughnes,
                        'metallic': metallic,
                        },
                    },

                    "projector": {
                        "type": "projector_py",
                        "irradiance": {
                            # "type": "ref",
                            # "id": "proj_texture",
                            "type": "bitmap",
                            'filename': '/home/dcor/niskhizov/AdversarialRendering/mitsuba/mat_data/WoodFloor064_1K/WoodFloor064_1K-JPG_Color.jpg',
                            # "raw": True,  # assuming the image is in linear RGB
                            'format' : 'variant'
                        },
                        "scale": proj_brightness,
                        "to_world": mi.ScalarTransform4f().look_at(
                            origin=[0.005, 0, 0],  # along +X axis
                            target=[0, 0, 0],
                            up=[0, 0, 1],  # Z-up
                        ),
                        "fov": proj_fov,
                        "response_mode": proj_response_mode,
                    },
                    
                    "ambient": {
                        "type": "constant",
                        "radiance": {"type": "rgb", "value": ambient_color},
                    },
                }
    
    return scene_dict
# params = mi.traverse(scene)

import torch



@dr.wrap(source='torch', target='drjit')
def render_texture2(params, proj_tex_grad):



    params['projector.irradiance.data'] = proj_tex_grad 
    params.update()

    raw_render = mi.render(scene, params)



    return raw_render

def render(params, proj_tex_grad):

    scene_params = params['scene']
    cam_params = params['cam_params']

    raw_render = render_texture2(scene_params,proj_tex_grad)


    alpha = raw_render[:, :, -1:]
    image = raw_render[:, :, :3]
    # no_alpha_render = gsoup.alpha_compose(render)
    image = tonemap_reinhard(image, exposure=1.0)
    # image = linear_to_srgb(image)
    final_image = add_alpha(image, alpha)

    final_image  = gaussian_blur_torch(final_image[:, :, :3].permute(2,0,1), cam_params['sigma']).permute(1,2,0)

    final_image_glow = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])

    final_image = final_image.clamp(0, 1.0)

    return final_image

def render2(params, proj_tex_grad):

    scene_params = params['scene']
    cam_params = params['cam_params']

    raw_render = render_texture2(scene_params,proj_tex_grad)


    alpha = raw_render[:, :, -1:]
    image = raw_render[:, :, :3]
    # no_alpha_render = gsoup.alpha_compose(render)
    image = tonemap_reinhard(image, exposure=1.0)
    # image = linear_to_srgb(image)
    final_image = add_alpha(image, alpha)

    final_image  = gaussian_blur_torch(final_image[:, :, :3].permute(2,0,1), cam_params['sigma']).permute(1,2,0)

    final_image_glow = gaussian_glow(final_image, cam_params['glow_radius'], cam_params['glow_strength'])

    final_image_glow = final_image_glow.clamp(0, 1.0)

    return final_image_glow, final_image



texture = cv2.imread('/home/dcor/niskhizov/AdversarialRendering/mitsuba/colorful_pattern.jpg')#gsoup.generate_voronoi_diagram(512, 512, 1000)*0+255
proj_texture = gsoup.to_float(texture)

scene_dict = generate_random_scene()

scene = mi.load_dict(scene_dict)


params = mi.traverse(scene)

# cam_params = {'sigma': 1.0}  # Example camera parameters, adjust as needed
# params = {'scene': params, 'cam_params': cam_params}

# proj_tex_grad = torch.from_numpy(proj_texture).requires_grad_(True).cuda()  # Convert to (C, H, W) format for PyTorch

# final_image = render(params, proj_tex_grad)

# plt.imshow(final_image.detach().cpu().numpy(), aspect='auto')
import torchvision

resizer = torchvision.transforms.Resize((256, 256))
# num_anchors = 10
# learnable_anchors = torch.rand(num_anchors, 3, 3, 3).cuda()  # Example learnable anchors
# learnable_anchors = learnable_anchors.requires_grad_(True)

proj_tex = torch.from_numpy(proj_texture).cuda() 
proj_tex_r = resizer(proj_tex.permute(2, 0, 1))

anchors = []#torch.rand(num_anchors, 3, 10, 10).cuda()  # Example learnable anchors
for i in range(len(anchors_paths)):
    anchor = cv2.imread(anchors_paths[i])
    anchor = cv2.cvtColor(anchor, cv2.COLOR_BGR2RGB)
    anchor = gsoup.to_float(anchor)
    anchor = torch.from_numpy(anchor).permute(2, 0, 1).cuda()  # Convert to (C, H, W) format
    anchors.append(anchor)
anchors = torch.stack(anchors).cuda()  # Stack anchors into a single tensor
    
num_anchors = anchors.shape[0]



class AnchorsCnnDownsample(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(AnchorsCnnDownsample, self).__init__()
        self.layers = torch.nn.Sequential(
            torch.nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 16, kernel_size=3, stride=2, padding=1),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 16, kernel_size=3, stride=2, padding=1),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 16, kernel_size=3, stride=2, padding=1),
            torch.nn.ReLU(),
        )
        self.deconv = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(num_anchors*16, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            torch.nn.ReLU(),
            torch.nn.ConvTranspose2d(16, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            torch.nn.ReLU(),
            torch.nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=1, output_padding=1),
            torch.nn.ReLU(),
            torch.nn.ConvTranspose2d(8, 3, kernel_size=3, stride=2, padding=1, output_padding=1),
        )


        # self.fc =  torch.nn.Sequential(
        #     torch.nn.Linear(8 * 16 * 16, 32),  # Assuming input size is 400x400
        #     torch.nn.ReLU(),
        #     torch.nn.Linear(32, 32),  
        #     torch.nn.ReLU(),
        # )

        # self.fc2 = torch.nn.Sequential(torch.nn.Linear(32*learnable_anchors.shape[0], 1024),
        #                                 torch.nn.ReLU(),
        #                                 torch.nn.Linear(1024, 1024),
        #                                 torch.nn.ReLU(),
                                       
                                       
        #                                )

    def forward(self, x):
        # print(x.shape)
        x = self.layers(x)#.reshape(3*learnable_anchors.shape[0], 256, 256))  
        # print(x.shape)
        x = self.deconv(x.reshape(num_anchors*16, 16, 16))  
        # print(x.shape)
        # x = x.reshape(x.size(0), -1)  # Flatten the tensor
        # x = self.fc(x)
        # x = x.reshape(-1)
        # x = self.fc2(x)
        return x
    

import torch.nn as nn

class LightCNN(nn.Module):
    def __init__(self):
        super(LightCNN, self).__init__()
        self.im_encoder = nn.Conv2d(3, 32, kernel_size=3, padding=1)  # 4x60x80 -> 8x60x80
        self.anchor_encoder = nn.Conv2d(num_anchors*3, num_anchors, kernel_size=3, padding=1, groups=num_anchors)  # 4x60x80 -> 8x60x80
        self.encoder = nn.Sequential(
            nn.Conv2d(32+num_anchors, 32, kernel_size=3, padding=1),  # 4x60x80 -> 8x60x80
            nn.LeakyReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1), # 8x60x80 -> 16x60x80
            nn.LeakyReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1), # 8x60x80 -> 16x60x800
            nn.LeakyReLU(),
            nn.Conv2d(32, 16, kernel_size=3, padding=1), # 8x60x80 -> 16x60x80
            nn.LeakyReLU(),
        )
        self.decoder = nn.Sequential(
            nn.Conv2d(16, 8, kernel_size=3, padding=1), # 16x60x80 -> 8x60x80
            nn.LeakyReLU(),
            nn.Conv2d(8, 3, kernel_size=3, padding=1) )  # 8x60x80 -> 4x60x80
        


    def forward(self, x, condition):
        im_enc = self.im_encoder(x)
        anchor_enc = self.anchor_encoder(condition)
        x = torch.cat([im_enc, anchor_enc], dim=0)
        x = self.encoder(x)
        x = self.decoder(x)
        return x


ckpt_dir = 'v8_fixed_ckpt'
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
# cnn_ds = AnchorsCnnDownsample(3, 64).cuda()
model = LightCNN().cuda()  

if os.path.exists(f'{ckpt_dir}/light_cnn.pth') :
    print('Loading existing models...')
    # learnable_anchors = torch.load(f'{ckpt_dir}/learnable_anchors.pth').cuda()
    light_cnn_sd = torch.load(f'{ckpt_dir}/light_cnn.pth')
    # cnn_downsample_sd = torch.load(f'{ckpt_dir}/cnn_downsample.pth')
    # cnn_ds.load_state_dict(cnn_downsample_sd)
    model.load_state_dict(light_cnn_sd)
else:
    print('No existing models found, initializing new ones...')
    

from torch import optim

  



optimizer = optim.Adam([*model.parameters()], lr=1e-3)
# freeze the learnable anchors
# learnable_anchors = learnable_anchors.requires_grad_(False)
# optimizer = optim.Adam([*cnn_ds.parameters(), *model.parameters()], lr=1e-3)



mi.set_log_level(mi.LogLevel.Error)  # Suppress Mitsuba logs
import tqdm
proj_tex_r.shape
from torchmetrics.image import TotalVariation
tv = TotalVariation().cuda()
caltec_photos = '/home/dcor/niskhizov/caltech-101/101_ObjectCategories/'
ls = glob.glob(caltec_photos + '/*/*.jpg')

start_time = str(datetime.now()).split('.')[0]

experiment = comet_ml.Experiment(display_summary_level=0, log_code=True)

anchor_size = anchors.shape[2]
exp_name = f'{num_anchors}_anchors_{anchor_size}x{anchor_size}_16c_condition'

complete_name = exp_name+'_'+start_time

experiment.set_name(complete_name)
experiment.log_code()

attempts_per_scene = 10

experiment.log_parameters({
    'num_anchors': num_anchors,
    'anchor_size': anchors.shape[2],
    'anchor_channels': anchors.shape[1],
    'cam_wh': cam_wh,
    'cam_fov': cam_fov,
    'proj_wh': proj_wh,
    'proj_fov': proj_fov,
    'spp': spp,
    'proj_response_mode': proj_response_mode,
    'exp_name': complete_name,
    'ckpt_dir': ckpt_dir,
    })
watch(model)
# watch(cnn_ds)

L1 = nn.L1Loss()


def generate_cam_params():
    sigma = np.random.uniform(1, 4)  # Random sigma for Gaussian blur
    glow_radius = np.random.randint(10, 60)  # Random glow radius
    glow_strength = np.random.uniform(1.0, 10.0)  # Random glow strength

    return {'sigma':sigma, 'glow_radius': glow_radius, 'glow_strength': glow_strength}

for epoch in tqdm.tqdm(range(10000)):

    cam_params = generate_cam_params()
    scene_dict = generate_random_scene()
    scene = mi.load_dict(scene_dict)
    params = {'scene':mi.traverse(scene), 'cam_params': cam_params}

    optimizer.zero_grad()

    # Resize the learnable anchors to match the input size
    projected_anchors = []

    for anchor in anchors:
        resized_anchor = resizer(anchor)  # Change to HWC format
        projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
    
    projected_anchors = torch.stack(projected_anchors) 
    # raise

    condition = projected_anchors.permute(0,3,1,2)#cnn_ds(projected_anchors.permute(0,3,1,2))
    condition = condition.reshape(-1,condition.shape[2], condition.shape[3])

    outputs = []
    true_projs = []
    for attempt in range(attempts_per_scene):
        # Randomly select a Caltech photo for texture
        random_caltech_photo = np.random.choice(ls[:-100])
        texture = cv2.cvtColor(cv2.imread(random_caltech_photo), cv2.COLOR_BGR2RGB)#gsoup.generate_voronoi_diagram(512, 512, 1000)*0+255
        proj_texture = gsoup.to_float(texture)
        proj_tex = torch.from_numpy(proj_texture).cuda() 
        proj_tex_r = resizer(proj_tex.permute(2, 0, 1))

        true_proj = render(params, proj_tex_r.permute(1,2,0))

        # model_input = torch.cat([proj_tex_r, condition])
        output = model(proj_tex_r,condition)

        outputs.append(output)
        true_projs.append(true_proj.permute(2,0,1))  # Ensure
    

    outputs = torch.stack(outputs)  # Shape: (attempts_per_scene, C, H, W)
    true_projs = torch.stack(true_projs)  # Shape: (attempts_per_scene, C, H, W)
    
    tv_loss = tv(anchors) / 10000
    
    loss = L1(outputs, true_projs) # + tv_loss# Ensure true_proj is in (C, H, W) format
    
    loss.backward()

    # clip gradients to avoid exploding gradients
    # learnable_anchors_grad = learnable_anchors.grad
    # cnn_ds_grad = torch.nn.utils.clip_grad_norm_(cnn_ds.parameters(), max_norm=10.0)
    model_grad = torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=10.0)
    

    optimizer.step()

    if epoch % 10 == 0:
        experiment.log_metrics({
            "loss": loss.item(),
            "tv_loss": tv_loss.item(),
            # "learnable_anchors_grad_mean": learnable_anchors_grad.mean().item(),
            # "cnn_ds_grad": cnn_ds_grad,
            "model_grad": model_grad,
        }, step=epoch)

        
    if (epoch) % 100 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item()}")
        plt.imshow(output.permute(1,2,0).detach().cpu().numpy(), aspect='auto')
        plt.show()
        plt.imshow(true_proj.detach().cpu().numpy(), aspect='auto')
        plt.show()

        # Save the model state
        # torch.save(learnable_anchors, f'{ckpt_dir}/learnable_anchors.pth')
        torch.save(model.state_dict(), f'{ckpt_dir}/light_cnn.pth')
        # torch.save(cnn_ds.state_dict(), f'{ckpt_dir}/cnn_downsample.pth')
        # Save the current learnable anchors
        with torch.no_grad():
            
            scene_dict = generate_random_scene(test=True)
            scene = mi.load_dict(scene_dict)
            params = mi.traverse(scene)         
            cam_params = generate_cam_params()
            params = {'scene': params, 'cam_params': cam_params}

            # Resize the learnable anchors to match the input size
            projected_anchors = []

            for anchor in anchors:
                resized_anchor = resizer(anchor)  # Change to HWC format
                projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))

            projected_anchors = torch.stack(projected_anchors) 
            # raise

            condition = projected_anchors.permute(0,3,1,2)#cnn_ds(projected_anchors.permute(0,3,1,2))
            condition = condition.reshape(-1,condition.shape[2], condition.shape[3])

            random_caltech_photo = np.random.choice(ls[:-100])
            texture = cv2.cvtColor(cv2.imread(random_caltech_photo), cv2.COLOR_BGR2RGB)#gsoup.generate_voronoi_diagram(512, 512, 1000)*0+255
            proj_texture = gsoup.to_float(texture)
            proj_tex = torch.from_numpy(proj_texture).cuda() 
            proj_tex_r = resizer(proj_tex.permute(2, 0, 1))

            true_proj = render(params, proj_tex_r.permute(1,2,0))

            # model_input = torch.cat([proj_tex_r, condition])
            output = model(proj_tex_r,condition)

        experiment.log_image(output.permute(1,2,0).detach().cpu().numpy(), name=f'output.png', step=epoch)
        experiment.log_image(true_proj.detach().cpu().numpy(), name=f'true_proj.png', step=epoch)
        experiment.log_image(proj_tex_r.permute(1,2,0).detach().cpu().numpy(), name=f'proj_tex_r.png', step=epoch)
        experiment.log_image(texture, name=f'texture.png', step=epoch)
        

        # for i in range(learnable_anchors.shape[0]):
        #     experiment.log_image(learnable_anchors[i].cpu().detach().numpy().transpose(1, 2, 0), name=f'learnable_anchor_{i}.png', step=epoch)
# Out:
# Loading existing models...
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dannynis/fewshotadapter/b271db4ce8bc44849512cfa7b243a916
#
# COMET WARNING: unable to find caller source code in a jupyter notebook; ignoring
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.01743663102388382
#   0%|          | 0/10000 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/mitsuba/python/util.py:357, in _RenderOp.eval(self, scene, sensor, _, params, integrator, seed, spp)
#     356 with dr.suspend_grad():
# --> 357     return self.integrator.render(
#     358         scene=self.scene,
#     359         sensor=sensor,
#     360         seed=seed[0],
#     361         spp=spp[0],
#     362         develop=True,
#     363         evaluate=False
#     364     )
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 600
#     598 for anchor in anchors:
#     599     resized_anchor = resizer(anchor)  # Change to HWC format
# --> 600     projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))
#     602 projected_anchors = torch.stack(projected_anchors)
#     603 # raise
#
# Cell In[7], line 260, in render(params, proj_tex_grad)
#     257 scene_params = params['scene']
#     258 cam_params = params['cam_params']
# --> 260 raw_render = render_texture2(scene_params,proj_tex_grad)
#     263 alpha = raw_render[:, :, -1:]
#     264 image = raw_render[:, :, :3]
#
# File ~/anaconda3/lib/python3.12/site-packages/drjit/interop.py:632, in wrap.<locals>.wrapper.<locals>.wrapper_2(*args, **kwargs)
#     630 def wrapper_2(*args, **kwargs):
#     631     global torch_desc_o
# --> 632     rv = torch_wrapper.apply(func, *flatten((args, kwargs)))
#     633     rv = unflatten(torch_desc_o, *rv)
#     634     torch_desc_o = None
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/anaconda3/lib/python3.12/site-packages/drjit/interop.py:411, in create_torch_wrapper.<locals>.TorchWrapper.forward(ctx, func, desc, *inputs)
#     407 global torch_desc_o
#     408 with torch_set_grad_enabled(True):
#     409     # Torch autograd tracing is disabled within `Function.forward`
#     410     # we turn it back on here in case func itself uses torch
# --> 411     torch_desc_o, *output = flatten(func(*args, **kwargs))
#     412 output = wrap_into_tensor(output)
#     414 # Stash inputs and outputs for later use
#
# Cell In[7], line 249, in render_texture2(params, proj_tex_grad)
#     246 params['projector.irradiance.data'] = proj_tex_grad
#     247 params.update()
# --> 249 raw_render = mi.render(scene, params)
#     253 return raw_render
#
# File ~/anaconda3/lib/python3.12/site-packages/mitsuba/python/util.py:508, in render(scene, params, sensor, integrator, seed, seed_grad, spp, spp_grad)
#     495     return integrator.render(
#     496             scene=scene,
#     497             sensor=sensor,
#    (...)
#     501             evaluate=False
#     502         )
#     504 # Both `dict_params` and `params` are passed. The former is necessary
#     505 # because it allows the custom operation to detect any attached input
#     506 # arguments. The latter is necessary because it will not be automatically
#     507 # detached by the custom operation.
# --> 508 return dr.custom(_RenderOp, scene, sensor, dict_params, params, integrator,
#     509                  (seed, seed_grad), (spp, spp_grad))
#
# RuntimeError: drjit.custom(<mitsuba.python.util._RenderOp>): error while performing a custom differentiable operation. (see above).

# %%
params['scene']['wall3.bsdf.metallic.value'] = 0.01

# %%
params['scene']['projector.scale'] =  3

# %%
with torch.no_grad():
            
            # scene_dict = generate_random_scene(test=True)
            # scene = mi.load_dict(scene_dict)
            # params = mi.traverse(scene)         
            # cam_params = generate_cam_params()
            # params = {'scene': params, 'cam_params': cam_params}

            # Resize the learnable anchors to match the input size
            projected_anchors = []

            for anchor in anchors:
                resized_anchor = resizer(anchor)  # Change to HWC format
                projected_anchors.append(render(params, resized_anchor.permute(1,2,0)))

            projected_anchors = torch.stack(projected_anchors) 
            # raise

            condition = projected_anchors.permute(0,3,1,2)#cnn_ds(projected_anchors.permute(0,3,1,2))
            condition = condition.reshape(-1,condition.shape[2], condition.shape[3])

            random_caltech_photo = np.random.choice(ls[:-100])
            texture = cv2.cvtColor(cv2.imread(random_caltech_photo), cv2.COLOR_BGR2RGB)#gsoup.generate_voronoi_diagram(512, 512, 1000)*0+255
            proj_texture = gsoup.to_float(texture)
            proj_tex = torch.from_numpy(proj_texture).cuda() 
            proj_tex_r = resizer(proj_tex.permute(2, 0, 1))

            true_proj = render(params, proj_tex_r.permute(1,2,0))

            # model_input = torch.cat([proj_tex_r, condition])
            output = model(proj_tex_r,condition)

            plt.imshow(output.permute(1,2,0).detach().cpu().numpy(), aspect='auto')
            plt.show()
            plt.imshow(true_proj.detach().cpu().numpy(), aspect='auto')
            plt.show()
            plt.imshow(proj_tex_r.permute(1,2,0).detach().cpu().numpy(), aspect='auto')
            plt.show()

# %%
true_projg,tp = render2(params, proj_tex_r.permute(1,2,0))

# %%
# %matplotlib inline

# %%
plt.imshow(tp.cpu().numpy(), aspect='auto')

# %%
cam_params['glow_radius']

# %%
import copy
def gaussian_blur_torch(image, sigma):

    device = image.device if hasattr(image, 'device') else 'cpu'

    # Create Gaussian kernel
    kernel_size = int(2 * sigma * 3) + 1  # 6 sigma rule
    if kernel_size % 2 == 0:
        kernel_size += 1
    
    # Create 1D Gaussian kernel - ensure it's on the same device
    x = torch.arange(kernel_size, dtype=torch.float32, device=device) - kernel_size // 2
    gauss_1d = torch.exp(-(x ** 2) / (2 * sigma ** 2))
    gauss_1d = gauss_1d / gauss_1d.sum()
    
    # Create 2D kernel
    gauss_2d = gauss_1d.unsqueeze(0) * gauss_1d.unsqueeze(1)
    gauss_2d = gauss_2d.unsqueeze(0).unsqueeze(0)

    gauss_2d_rgb = gauss_2d.repeat(3, 1, 1, 1)  # Repeat for RGB channels
    
    # Apply convolution with padding
    padding = kernel_size // 2

    masked_image = copy.deepcopy(image)
    masked_image_c = copy.deepcopy(image)

    # masked_image[:,(masked_image.sum(0) < 2 )] = 0

    # masked_image_c[:,(masked_image.sum(0) > 2)] = 0

    blurred = F.conv2d(masked_image, gauss_2d_rgb, padding=padding,groups=3)

    final = (blurred + masked_image_c) 
    
    return  final 
#blurred.squeeze(0).squeeze(0)

# %%
import matplotlib.pyplot as plt

o = gaussian_blur_torch(proj_tex_r,100)
plt.imshow(o.permute(1, 2, 0).detach().cpu().numpy())
plt.show()

# %%
plt.imshow(proj_tex_r.permute(1, 2, 0).detach().cpu().numpy())
plt.show()
